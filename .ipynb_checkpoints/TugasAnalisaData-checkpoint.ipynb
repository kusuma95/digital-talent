# %% [markdown]
# ## Projects
#
# Temukan data yang menurut kalian menarik pada http://data.go.id . Buat analisa data yang berisi:
# 1. Deskripsi Data
# 2. Statistik tentang data
# 3. Visualisasi sederhana
# 4. Narasi analisis
#
# Buat dalam sebuah Notebook dengan judul Analisa Data X, dimana X adalah Deskripsi Data yang dianalisa. Submit link menuju notebooknya di elisa.

# %% [markdown]
# ### [1] Deskripsi Data
#
# Dataset ini berisi data mengenai jumlah anak dengan status kesejahteraan 30% yang bersekolah berdasarkan tingkat pendidikan dan jenis kelamin Tahun 2012.
# Sumber dari TNP2K yang diambil per Juli 2012. Tim Nasional Percepatan Penanggulangan Kemiskinan (TNP2K) adalah lembaga yang dibentuk untuk menangani dan berkoordinasi dalam hal-hal yang berkaitan dengan penanggulangan dan pengentasan kemiskinan di Republik Indonesia. (data.go.id)

# %%
import pandas as pd
import matplotlib

# Menampilkan data dalam bentuk tabel
data_pendidikan = pd.read_csv('processed-jumlah-partisipasi-sekolah-jenis-kelamin-30persen-termiskin-indonesia-perjuli2012.csv', delimiter = ',', encoding = "ISO-8859-1")
data_pendidikan
# Out:
#      kode_provinsi                   nama_provinsi     tingkat_pendidikan  \
# 0               11  Prov. Nanggroe Aceh Darussalam              M. Aliyah
# 1               11  Prov. Nanggroe Aceh Darussalam              M. Aliyah
# 2               11  Prov. Nanggroe Aceh Darussalam          M. Ibtidaiyah
# 3               11  Prov. Nanggroe Aceh Darussalam          M. Ibtidaiyah
# 4               11  Prov. Nanggroe Aceh Darussalam          M. Tsanawiyah
# 5               11  Prov. Nanggroe Aceh Darussalam          M. Tsanawiyah
# 6               11  Prov. Nanggroe Aceh Darussalam       Perguruan Tinggi
# 7               11  Prov. Nanggroe Aceh Darussalam       Perguruan Tinggi
# 8               11  Prov. Nanggroe Aceh Darussalam        SD/SDLB/Paket A
# 9               11  Prov. Nanggroe Aceh Darussalam        SD/SDLB/Paket A
# 10              11  Prov. Nanggroe Aceh Darussalam  SMA/SMK/SMALB/Paket C
# 11              11  Prov. Nanggroe Aceh Darussalam  SMA/SMK/SMALB/Paket C
# ...

# %%
# Menampilkan kolom yang terdapat pada tabel
data_pendidikan.columns
# Out:
# Index(['kode_provinsi', 'nama_provinsi', 'tingkat_pendidikan', 'jenis_kelamin',
#        'jumlah_individu'],
#       dtype='object')

# %%
# Menghitung jumlah data pada tabel
data_pendidikan.count()
# Out:
# kode_provinsi         462
# nama_provinsi         462
# tingkat_pendidikan    462
# jenis_kelamin         462
# jumlah_individu       462
# dtype: int64

# %%
# Mengetahui jumlah total individu miskin berdasarkan tingkat pendidikan
total = data_pendidikan.sum()['jumlah_individu']
print('Total individu: ',total, 'jiwa')
# Out:
# Total individu:  17601023 jiwa

# %%
# Mengetahui statistik sederhana dari tabel status kesejahteraan
min = data_pendidikan.min()['jumlah_individu']
print('Data terkecil: ', min, 'jiwa')
# Out:
# Data terkecil:  22 jiwa

# %%
max = data_pendidikan.max()['jumlah_individu']
print('Data terkecil: ', max, 'jiwa')
# Out:
# Data terkecil:  972960 jiwa

# %%
mean = data_pendidikan.mean()['jumlah_individu']
print('Rata-rata: ', round(mean,0))
# Out:
# Rata-rata:  38097.0

# %% [markdown]
# ### [2] Statistik tentang data

# %%
# Menampilkan data jumlah individu berdasarkan tingkat pendidikannya
data_pendidikan.groupby('tingkat_pendidikan').sum()['jumlah_individu']
# Out:
# tingkat_pendidikan
# M. Aliyah                  135469
# M. Ibtidaiyah              694415
# M. Tsanawiyah              504282
# Perguruan Tinggi           177305
# SD/SDLB/Paket A          10938888
# SMA/SMK/SMALB/Paket C     1696975
# SMPT/SMPLB/Paket B        3453689
# Name: jumlah_individu, dtype: int64

# %% [markdown]
# ### [3] Visualisasi Sederhana

# %%
# Visualisai untuk menuntujukkan perbandingan jumlah individu Laki-laki dan Perempuan
ax = data_pendidikan.groupby('jenis_kelamin').sum()['jumlah_individu']
ax = ax.plot(kind='pie', title ="Perbandingan jumlah individu berdasarkan jenis kelamin", legend=False, figsize=(6,6), fontsize=10)

# %%
# Visualisasiuntuk menunjukkan jumlah individu status kesejahteraan di setiap provinsi
ax = data_pendidikan.groupby('kode_provinsi').sum()['jumlah_individu']
ax = ax.plot(kind='bar', title ="Jumlah Individu setiap Provinsi", legend=False, fontsize=10, figsize=(15,7))
Jumlah = [0,10000,20000,30000,40000,50000,60000]
ax.set_xlabel("Kode Provinsi", fontsize=12)
ax.set_ylabel("Jumlah", fontsize=12)
# Out:
# Text(0,0.5,'Jumlah')

# %%
# Visualisasiuntuk menunjukkan jumlah individu status kesejahteraan di setiap provinsi
ax = data_pendidikan.groupby('tingkat_pendidikan').sum()['jumlah_individu']
ax = ax.plot(kind='pie', title ="Jumlah Individu setiap tingkat Pendidikan", legend=False, fontsize=10, figsize=(10,10))
ax.set_xlabel("Jumlah", fontsize=12)
ax.set_ylabel("Tingkat Pendidikan", fontsize=12)
# Out:
# Text(0,0.5,'Tingkat Pendidikan')

# %% [markdown]
# ### [4] Narasi Analisis

# %% [markdown]
# 1. Visualisasi pada grafik pertama menunjukkan bahwa jumlah angka kemiskinan pada jenis kelamin laki-laki lebih banyak dibandingkan dengan angka kemiskinan pada jenis kelamin perempuan.
# 2. Visualisasi pada grafik kedua menunjukkan bahwa angka kemiskinan tertinggi pada kode provinsi 32 yaitu provinsi Jawa Barat.
# 3. Visualisasi pada grafik ketiga menunjukkan bahwa angka kemiskinan tertinggi terdapat pada tingkat pendidikan SD/SDLB/Paket A.
